# %% [markdown]
# <a href="https://www.kaggle.com/code/hienvm/alexnet-pretrained-skin-diagnosis?scriptVersionId=211186752" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import sys
sys.path.append('/kaggle/input/alexnet/pytorch/improved/1')
import torch
import torch.nn as nn
from torchvision import datasets
from improved.model import AlexNetImproved, init_params
from improved.data_transforms import prepreprocess, get_preprocess, get_train_augment, calc_mean_std
from improved.pca import pca
from improved.train import train
import matplotlib.pyplot as plt
from improved.eval import top1_k

# %%
torch.manual_seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# train_dataset = datasets.ImageFolder('/kaggle/input/skin-diagnosis/Train', transform=prepreprocess)
# mean, std = calc_mean_std(train_dataset)
# print(f'Mean:\n{mean}')
# print(f'Standard Deviation:\n{std}')
# preprocess = get_preprocess(mean, std)

# train_dataset = datasets.ImageFolder('/kaggle/input/skin-diagnosis/Train', transform=preprocess)
# eigvals, eigvecs = pca(train_dataset)
# train_augment = get_train_augment(eigvals, eigvecs, mean, std)

preprocess = torch.load('/kaggle/input/alexnet-pretrain/pytorch/improved-imagenette/1/improved_imagenette.preprocess.pt')
train_augment = torch.load('/kaggle/input/alexnet-pretrain/pytorch/improved-imagenette/1/improved_imagenette.train_augment.pt')

train_dataset = datasets.ImageFolder('/kaggle/input/skin-diagnosis/Train', transform=train_augment)

val_dataset =datasets.ImageFolder('/kaggle/input/skin-diagnosis/Test', transform=preprocess)
# val_dataset, test_dataset = torch.utils.data.random_split(val_dataset, [0.5, 0.5])
test_dataset = val_dataset

print(f'Train samples: {len(train_dataset)}')
print(f'Validation samples: {len(val_dataset)}')
print(f'Test samples: {len(test_dataset)}')
print(f'Number of classes: {len(train_dataset.classes)}')
print(train_dataset.class_to_idx)
# Out:
# /tmp/ipykernel_23/3390229920.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   preprocess = torch.load('/kaggle/input/alexnet-pretrain/pytorch/improved-imagenette/1/improved_imagenette.preprocess.pt')
# /tmp/ipykernel_23/3390229920.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_augment = torch.load('/kaggle/input/alexnet-pretrain/pytorch/improved-imagenette/1/improved_imagenette.train_augment.pt')
# Train samples: 2322
# Validation samples: 140
# Test samples: 140
# Number of classes: 10
# {'actinic keratosis': 0, 'basal cell carcinoma': 1, 'dermatofibroma': 2, 'healthy': 3, 'melanoma': 4, 'nevus': 5, 'pigmented benign keratosis': 6, 'seborrheic keratosis': 7, 'squamous cell carcinoma': 8, 'vascular lesion': 9}

# %%
model = AlexNetImproved(len(train_dataset.classes))
model.load_state_dict(torch.load('/kaggle/input/alexnet-pretrain/pytorch/improved-imagenette/1/improved_imagenette.model.pt'))
if torch.cuda.device_count() > 1:
    print(f'Using {torch.cuda.device_count()} GPUs.')
    model = nn.DataParallel(model)
model.to(device)
freeze = 1
for i in range(freeze):
    for p in model.conv_layers[i].parameters():
        p.requires_grad = False
# initialize parameters
# init_params(model)
compiled_model = model
# if torch.cuda.is_available():
#     compiled_model = torch.compile(model)
print(f'Freezed first {freeze} layers.')
# Out:
# /tmp/ipykernel_23/139663850.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/kaggle/input/alexnet-pretrain/pytorch/improved-imagenette/1/improved_imagenette.model.pt'))
# Freezed first 1 layers.

# %%
costs, val_error_rates, learning_rates = train(
    compiled_model,
    train_dataset=train_dataset,
    cv_dataset=val_dataset,
    batch_size=128,
    num_epochs=200,
    initial_lr=0.01,
    num_workers=3,
    patience=20,
    optimizer='sgd'
)
# Out:
# Epoch 1/200, Cost: 3.161, Val Error: 77.14%, lr: 0.01, Time: 32s
# Epoch 2/200, Cost: 2.157, Val Error: 60.00%, lr: 0.01, Time: 28s
# Epoch 3/200, Cost: 1.977, Val Error: 55.71%, lr: 0.01, Time: 28s
# Epoch 4/200, Cost: 2.023, Val Error: 57.86%, lr: 0.01, Time: 26s
# Epoch 5/200, Cost: 2.168, Val Error: 56.43%, lr: 0.01, Time: 26s
# Epoch 6/200, Cost: 2.099, Val Error: 59.29%, lr: 0.01, Time: 27s
# Epoch 7/200, Cost: 1.847, Val Error: 49.29%, lr: 0.01, Time: 28s
# Epoch 8/200, Cost: 1.635, Val Error: 49.29%, lr: 0.01, Time: 26s
# Epoch 9/200, Cost: 1.576, Val Error: 53.57%, lr: 0.01, Time: 27s
# Epoch 10/200, Cost: 1.511, Val Error: 48.57%, lr: 0.01, Time: 27s
# Epoch 11/200, Cost: 1.525, Val Error: 45.00%, lr: 0.01, Time: 29s
# Epoch 12/200, Cost: 1.380, Val Error: 43.57%, lr: 0.01, Time: 28s
# Epoch 13/200, Cost: 1.395, Val Error: 49.29%, lr: 0.01, Time: 27s
# Epoch 14/200, Cost: 1.322, Val Error: 49.29%, lr: 0.01, Time: 28s
# Epoch 15/200, Cost: 1.352, Val Error: 50.00%, lr: 0.01, Time: 28s
# Epoch 16/200, Cost: 1.286, Val Error: 50.00%, lr: 0.01, Time: 27s
# Epoch 17/200, Cost: 1.235, Val Error: 45.71%, lr: 0.01, Time: 28s
# Epoch 18/200, Cost: 1.201, Val Error: 39.29%, lr: 0.01, Time: 28s
# Epoch 19/200, Cost: 1.119, Val Error: 43.57%, lr: 0.01, Time: 27s
# Epoch 20/200, Cost: 1.183, Val Error: 45.71%, lr: 0.01, Time: 27s
# Epoch 21/200, Cost: 1.184, Val Error: 44.29%, lr: 0.01, Time: 27s
# Epoch 22/200, Cost: 1.235, Val Error: 44.29%, lr: 0.01, Time: 27s
# Epoch 23/200, Cost: 1.212, Val Error: 47.86%, lr: 0.01, Time: 27s
# Epoch 24/200, Cost: 1.165, Val Error: 48.57%, lr: 0.01, Time: 27s
# Epoch 25/200, Cost: 1.259, Val Error: 47.14%, lr: 0.01, Time: 27s
# Epoch 26/200, Cost: 1.151, Val Error: 49.29%, lr: 0.01, Time: 27s
# Epoch 27/200, Cost: 1.178, Val Error: 42.14%, lr: 0.01, Time: 27s
# Epoch 28/200, Cost: 1.182, Val Error: 40.00%, lr: 0.01, Time: 26s
# Epoch 29/200, Cost: 1.129, Val Error: 45.71%, lr: 0.01, Time: 26s
# Epoch 30/200, Cost: 1.115, Val Error: 45.71%, lr: 0.01, Time: 26s
# Epoch 31/200, Cost: 1.041, Val Error: 47.86%, lr: 0.01, Time: 27s
# Epoch 32/200, Cost: 1.001, Val Error: 44.29%, lr: 0.01, Time: 27s
# Epoch 33/200, Cost: 1.046, Val Error: 48.57%, lr: 0.01, Time: 27s
# Epoch 34/200, Cost: 1.066, Val Error: 46.43%, lr: 0.01, Time: 27s
# Epoch 35/200, Cost: 1.011, Val Error: 39.29%, lr: 0.01, Time: 26s
# Epoch 36/200, Cost: 1.102, Val Error: 44.29%, lr: 0.01, Time: 26s
# Epoch 37/200, Cost: 1.061, Val Error: 44.29%, lr: 0.01, Time: 28s
# Epoch 38/200, Cost: 1.014, Val Error: 43.57%, lr: 0.01, Time: 28s
# Epoch 39/200, Cost: 1.007, Val Error: 44.29%, lr: 0.001, Time: 26s
# Epoch 40/200, Cost: 0.891, Val Error: 42.14%, lr: 0.001, Time: 27s
# Epoch 41/200, Cost: 0.826, Val Error: 40.00%, lr: 0.001, Time: 27s
# Epoch 42/200, Cost: 0.829, Val Error: 35.71%, lr: 0.001, Time: 27s
# Epoch 43/200, Cost: 0.838, Val Error: 38.57%, lr: 0.001, Time: 27s
# Epoch 44/200, Cost: 0.826, Val Error: 39.29%, lr: 0.001, Time: 28s
# Epoch 45/200, Cost: 0.824, Val Error: 38.57%, lr: 0.001, Time: 27s
# Epoch 46/200, Cost: 0.848, Val Error: 37.86%, lr: 0.001, Time: 28s
# Epoch 47/200, Cost: 0.786, Val Error: 37.86%, lr: 0.001, Time: 27s
# Epoch 48/200, Cost: 0.766, Val Error: 37.86%, lr: 0.001, Time: 26s
# Epoch 49/200, Cost: 0.833, Val Error: 37.86%, lr: 0.001, Time: 27s
# Epoch 50/200, Cost: 0.807, Val Error: 38.57%, lr: 0.001, Time: 27s
# Epoch 51/200, Cost: 0.772, Val Error: 40.00%, lr: 0.001, Time: 27s
# Epoch 52/200, Cost: 0.765, Val Error: 38.57%, lr: 0.001, Time: 27s
# Epoch 53/200, Cost: 0.742, Val Error: 39.29%, lr: 0.001, Time: 28s
# Epoch 54/200, Cost: 0.751, Val Error: 37.14%, lr: 0.001, Time: 27s
# Epoch 55/200, Cost: 0.713, Val Error: 39.29%, lr: 0.001, Time: 26s
# Epoch 56/200, Cost: 0.721, Val Error: 40.00%, lr: 0.001, Time: 27s
# Epoch 57/200, Cost: 0.732, Val Error: 40.71%, lr: 0.001, Time: 28s
# Epoch 58/200, Cost: 0.732, Val Error: 39.29%, lr: 0.001, Time: 27s
# Epoch 59/200, Cost: 0.740, Val Error: 39.29%, lr: 0.001, Time: 27s
# Epoch 60/200, Cost: 0.687, Val Error: 38.57%, lr: 0.001, Time: 27s
# Epoch 61/200, Cost: 0.732, Val Error: 39.29%, lr: 0.001, Time: 27s
# Epoch 62/200, Cost: 0.754, Val Error: 39.29%, lr: 0.001, Time: 27s
# Epoch 63/200, Cost: 0.718, Val Error: 42.86%, lr: 0.0001, Time: 27s
# Epoch 64/200, Cost: 0.707, Val Error: 42.14%, lr: 0.0001, Time: 27s
# Epoch 65/200, Cost: 0.690, Val Error: 40.00%, lr: 0.0001, Time: 27s
# Epoch 66/200, Cost: 0.718, Val Error: 41.43%, lr: 0.0001, Time: 27s
# Epoch 67/200, Cost: 0.720, Val Error: 39.29%, lr: 0.0001, Time: 27s
# Epoch 68/200, Cost: 0.710, Val Error: 40.71%, lr: 0.0001, Time: 26s
# Epoch 69/200, Cost: 0.718, Val Error: 41.43%, lr: 0.0001, Time: 27s
# Epoch 70/200, Cost: 0.710, Val Error: 40.71%, lr: 0.0001, Time: 27s
# Epoch 71/200, Cost: 0.655, Val Error: 41.43%, lr: 0.0001, Time: 28s
# Epoch 72/200, Cost: 0.718, Val Error: 41.43%, lr: 0.0001, Time: 27s
# Epoch 73/200, Cost: 0.695, Val Error: 41.43%, lr: 0.0001, Time: 27s
# Epoch 74/200, Cost: 0.725, Val Error: 42.86%, lr: 0.0001, Time: 26s
# Epoch 75/200, Cost: 0.701, Val Error: 40.71%, lr: 0.0001, Time: 28s
# Epoch 76/200, Cost: 0.694, Val Error: 40.00%, lr: 0.0001, Time: 27s
# Epoch 77/200, Cost: 0.698, Val Error: 39.29%, lr: 0.0001, Time: 26s
# Epoch 78/200, Cost: 0.700, Val Error: 38.57%, lr: 0.0001, Time: 27s
# Epoch 79/200, Cost: 0.696, Val Error: 39.29%, lr: 0.0001, Time: 26s
# Epoch 80/200, Cost: 0.743, Val Error: 39.29%, lr: 0.0001, Time: 27s
# Epoch 81/200, Cost: 0.680, Val Error: 40.71%, lr: 0.0001, Time: 27s
# Epoch 82/200, Cost: 0.669, Val Error: 40.00%, lr: 0.0001, Time: 27s
# Epoch 83/200, Cost: 0.683, Val Error: 38.57%, lr: 0.0001, Time: 26s
# Epoch 84/200, Cost: 0.703, Val Error: 40.00%, lr: 1e-05, Time: 28s
# Epoch 85/200, Cost: 0.670, Val Error: 39.29%, lr: 1e-05, Time: 27s
# Epoch 86/200, Cost: 0.702, Val Error: 41.43%, lr: 1e-05, Time: 27s
# Epoch 87/200, Cost: 0.742, Val Error: 40.00%, lr: 1e-05, Time: 27s
# Epoch 88/200, Cost: 0.707, Val Error: 38.57%, lr: 1e-05, Time: 28s
# Epoch 89/200, Cost: 0.705, Val Error: 40.71%, lr: 1e-05, Time: 27s
# Epoch 90/200, Cost: 0.701, Val Error: 42.14%, lr: 1e-05, Time: 26s
# Epoch 91/200, Cost: 0.695, Val Error: 40.71%, lr: 1e-05, Time: 27s
# Epoch 92/200, Cost: 0.687, Val Error: 38.57%, lr: 1e-05, Time: 26s
# Epoch 93/200, Cost: 0.698, Val Error: 40.71%, lr: 1e-05, Time: 26s
# Epoch 94/200, Cost: 0.712, Val Error: 42.14%, lr: 1e-05, Time: 28s
# Epoch 95/200, Cost: 0.710, Val Error: 41.43%, lr: 1e-05, Time: 27s
# Epoch 96/200, Cost: 0.695, Val Error: 39.29%, lr: 1e-05, Time: 28s
# Epoch 97/200, Cost: 0.709, Val Error: 41.43%, lr: 1e-05, Time: 26s
# Epoch 98/200, Cost: 0.682, Val Error: 39.29%, lr: 1e-05, Time: 27s
# Epoch 99/200, Cost: 0.697, Val Error: 39.29%, lr: 1e-05, Time: 27s
# Epoch 100/200, Cost: 0.697, Val Error: 41.43%, lr: 1e-05, Time: 28s
# Epoch 101/200, Cost: 0.679, Val Error: 38.57%, lr: 1e-05, Time: 28s
# Epoch 102/200, Cost: 0.747, Val Error: 41.43%, lr: 1e-05, Time: 27s
# Epoch 103/200, Cost: 0.689, Val Error: 40.71%, lr: 1e-05, Time: 27s
# Epoch 104/200, Cost: 0.726, Val Error: 40.00%, lr: 1e-05, Time: 27s
# Epoch 105/200, Cost: 0.692, Val Error: 41.43%, lr: 1.0000000000000002e-06, Time: 28s
# Epoch 106/200, Cost: 0.714, Val Error: 40.71%, lr: 1.0000000000000002e-06, Time: 27s
# Epoch 107/200, Cost: 0.721, Val Error: 42.14%, lr: 1.0000000000000002e-06, Time: 28s
# Epoch 108/200, Cost: 0.723, Val Error: 39.29%, lr: 1.0000000000000002e-06, Time: 26s
# Epoch 109/200, Cost: 0.696, Val Error: 41.43%, lr: 1.0000000000000002e-06, Time: 27s
# Epoch 110/200, Cost: 0.717, Val Error: 40.71%, lr: 1.0000000000000002e-06, Time: 28s
# Epoch 111/200, Cost: 0.683, Val Error: 41.43%, lr: 1.0000000000000002e-06, Time: 28s
# Epoch 112/200, Cost: 0.691, Val Error: 39.29%, lr: 1.0000000000000002e-06, Time: 26s
# Epoch 113/200, Cost: 0.705, Val Error: 41.43%, lr: 1.0000000000000002e-06, Time: 26s
# Epoch 114/200, Cost: 0.689, Val Error: 40.71%, lr: 1.0000000000000002e-06, Time: 27s
# Epoch 115/200, Cost: 0.695, Val Error: 41.43%, lr: 1.0000000000000002e-06, Time: 27s
# Epoch 116/200, Cost: 0.683, Val Error: 40.71%, lr: 1.0000000000000002e-06, Time: 27s
# Epoch 117/200, Cost: 0.706, Val Error: 41.43%, lr: 1.0000000000000002e-06, Time: 26s
# Epoch 118/200, Cost: 0.707, Val Error: 39.29%, lr: 1.0000000000000002e-06, Time: 28s
# Epoch 119/200, Cost: 0.701, Val Error: 39.29%, lr: 1.0000000000000002e-06, Time: 27s
# Epoch 120/200, Cost: 0.701, Val Error: 39.29%, lr: 1.0000000000000002e-06, Time: 26s
# Epoch 121/200, Cost: 0.769, Val Error: 40.71%, lr: 1.0000000000000002e-06, Time: 28s
# Epoch 122/200, Cost: 0.706, Val Error: 37.86%, lr: 1.0000000000000002e-06, Time: 28s
# Epoch 123/200, Cost: 0.723, Val Error: 39.29%, lr: 1.0000000000000002e-06, Time: 27s
# Epoch 124/200, Cost: 0.688, Val Error: 40.71%, lr: 1.0000000000000002e-06, Time: 26s
# Epoch 125/200, Cost: 0.739, Val Error: 39.29%, lr: 1.0000000000000002e-06, Time: 27s
# Epoch 126/200, Cost: 0.678, Val Error: 40.00%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 127/200, Cost: 0.701, Val Error: 39.29%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 128/200, Cost: 0.706, Val Error: 39.29%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 129/200, Cost: 0.701, Val Error: 39.29%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 130/200, Cost: 0.672, Val Error: 40.00%, lr: 1.0000000000000002e-07, Time: 26s
# Epoch 131/200, Cost: 0.716, Val Error: 40.00%, lr: 1.0000000000000002e-07, Time: 26s
# Epoch 132/200, Cost: 0.680, Val Error: 38.57%, lr: 1.0000000000000002e-07, Time: 26s
# Epoch 133/200, Cost: 0.734, Val Error: 42.14%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 134/200, Cost: 0.641, Val Error: 40.00%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 135/200, Cost: 0.703, Val Error: 39.29%, lr: 1.0000000000000002e-07, Time: 26s
# Epoch 136/200, Cost: 0.671, Val Error: 40.00%, lr: 1.0000000000000002e-07, Time: 26s
# Epoch 137/200, Cost: 0.714, Val Error: 40.71%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 138/200, Cost: 0.699, Val Error: 39.29%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 139/200, Cost: 0.677, Val Error: 40.00%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 140/200, Cost: 0.736, Val Error: 38.57%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 141/200, Cost: 0.703, Val Error: 40.71%, lr: 1.0000000000000002e-07, Time: 26s
# Epoch 142/200, Cost: 0.713, Val Error: 41.43%, lr: 1.0000000000000002e-07, Time: 26s
# Epoch 143/200, Cost: 0.692, Val Error: 40.00%, lr: 1.0000000000000002e-07, Time: 26s
# Epoch 144/200, Cost: 0.690, Val Error: 37.86%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 145/200, Cost: 0.690, Val Error: 40.00%, lr: 1.0000000000000002e-07, Time: 27s
# Epoch 146/200, Cost: 0.725, Val Error: 41.43%, lr: 1.0000000000000002e-07, Time: 26s
# Epoch 147/200, Cost: 0.756, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 148/200, Cost: 0.693, Val Error: 41.43%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 149/200, Cost: 0.745, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 150/200, Cost: 0.694, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 151/200, Cost: 0.696, Val Error: 41.43%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 152/200, Cost: 0.675, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 153/200, Cost: 0.696, Val Error: 39.29%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 154/200, Cost: 0.676, Val Error: 41.43%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 155/200, Cost: 0.698, Val Error: 42.14%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 156/200, Cost: 0.690, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 157/200, Cost: 0.691, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 158/200, Cost: 0.679, Val Error: 39.29%, lr: 1.0000000000000004e-08, Time: 28s
# Epoch 159/200, Cost: 0.651, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 160/200, Cost: 0.709, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 161/200, Cost: 0.724, Val Error: 38.57%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 162/200, Cost: 0.667, Val Error: 39.29%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 163/200, Cost: 0.684, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 28s
# Epoch 164/200, Cost: 0.683, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 165/200, Cost: 0.701, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 166/200, Cost: 0.682, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 167/200, Cost: 0.684, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 168/200, Cost: 0.670, Val Error: 38.57%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 169/200, Cost: 0.700, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 170/200, Cost: 0.693, Val Error: 39.29%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 171/200, Cost: 0.720, Val Error: 38.57%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 172/200, Cost: 0.694, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 173/200, Cost: 0.665, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 174/200, Cost: 0.697, Val Error: 41.43%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 175/200, Cost: 0.667, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 28s
# Epoch 176/200, Cost: 0.656, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 28s
# Epoch 177/200, Cost: 0.737, Val Error: 38.57%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 178/200, Cost: 0.678, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 179/200, Cost: 0.663, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 180/200, Cost: 0.724, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 181/200, Cost: 0.684, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 182/200, Cost: 0.698, Val Error: 39.29%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 183/200, Cost: 0.677, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 184/200, Cost: 0.680, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 185/200, Cost: 0.684, Val Error: 41.43%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 186/200, Cost: 0.668, Val Error: 39.29%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 187/200, Cost: 0.715, Val Error: 37.86%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 188/200, Cost: 0.701, Val Error: 41.43%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 189/200, Cost: 0.712, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 190/200, Cost: 0.714, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 191/200, Cost: 0.674, Val Error: 39.29%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 192/200, Cost: 0.727, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 193/200, Cost: 0.716, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 194/200, Cost: 0.711, Val Error: 38.57%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 195/200, Cost: 0.680, Val Error: 40.71%, lr: 1.0000000000000004e-08, Time: 28s
# Epoch 196/200, Cost: 0.682, Val Error: 39.29%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 197/200, Cost: 0.697, Val Error: 39.29%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 198/200, Cost: 0.706, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 26s
# Epoch 199/200, Cost: 0.723, Val Error: 40.00%, lr: 1.0000000000000004e-08, Time: 27s
# Epoch 200/200, Cost: 0.699, Val Error: 38.57%, lr: 1.0000000000000004e-08, Time: 27s
# Training time: 90m

# %%
torch.save(model.state_dict(), 'skin.model.pt')
torch.save(preprocess, 'skin.preprocess.pt')
torch.save(train_augment, 'skin.train_augment.pt')

# %%
test_top1, test_top5 = top1_k(compiled_model, test_dataset, k=5)
print(f'Test Top 1: {test_top1}')
print(f'Test Top 5: {test_top5}')

val_top1, val_top5 = top1_k(compiled_model, val_dataset, k=5)
print(f'Val Top 1: {val_top1}')
print(f'Val Top 5: {val_top5}')

train_eval_dataset = datasets.ImageFolder('/kaggle/input/skin-diagnosis/Train', transform=preprocess)
train_top1, train_top5 = top1_k(compiled_model, train_eval_dataset, k=5)
print(f'Train Top 1: {train_top1}')
print(f'Train Top 5: {train_top5}')
# Out:
# Test Top 1: 0.6142857142857143
# Test Top 5: 0.9357142857142857
# Val Top 1: 0.6142857142857143
# Val Top 5: 0.9357142857142857
# Train Top 1: 0.9031007751937985
# Train Top 5: 0.9991386735572783

# %%
plt.plot(costs)
plt.xlabel("Epoch")
plt.title('Costs')
# Out:
# Text(0.5, 1.0, 'Costs')

# %%
plt.plot(val_error_rates)
plt.xlabel("Epoch")
plt.title('Validation Error Rates')
# Out:
# Text(0.5, 1.0, 'Validation Error Rates')

# %%
import math

plt.plot([math.log10(lr) for lr in learning_rates])
plt.ylabel("Log10(lr)")
plt.xlabel("Epoch")
plt.title('Learning Rates')
# Out:
# Text(0.5, 1.0, 'Learning Rates')
